# %%
import pandas as pd
import seaborn as sns

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# ### 1)Replace the NaN values with correct value. And Justify why you have chosen the same.

# %%
print("Before preprocess:",dataset.isna().sum())
#Nan values are present in salary column
# Out:
# Before preprocess: sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset['salary'].fillna(0,inplace=True)
#here i use fillna for nan values change for 0
# Out:
# C:\Users\RRDIL\AppData\Local\Temp\ipykernel_12856\3683289714.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['salary'].fillna(0,inplace=True)

# %%
print("after preprocess:",dataset.isna().sum())
#Nan values are changed  as 0 in salary column
# Out:
# after preprocess: sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          215 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %% [markdown]
# ### 2) - How many of them are non Placed?

# %%
dataset["status"].value_counts()
# Out:
# status
# Placed        148
# Not Placed     67
# Name: count, dtype: int64

# %% [markdown]
# ### 3)Find the reason for non-placement from the dataset?

# %%
dataset.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
dataset.drop(columns=['sl_no'],inplace=True)
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#store the data of not placed students
df_nonplaced=dataset[dataset['status']=='Not Placed']
df_nonplaced
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 3        M   56.0  Central   52.0  Central   Science     52.00   Sci&Tech
# 5        M   55.0   Others   49.8   Others   Science     67.25   Sci&Tech
# 6        F   46.0   Others   49.2   Others  Commerce     79.00  Comm&Mgmt
# 9        M   58.0  Central   70.0  Central  Commerce     61.00  Comm&Mgmt
# 12       F   47.0  Central   55.0   Others   Science     65.00  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 198      F   67.0  Central   70.0  Central  Commerce     65.00     Others
# 201      M   54.2  Central   63.0   Others   Science     58.00  Comm&Mgmt
# 206      M   41.0  Central   42.0  Central   Science     60.00  Comm&Mgmt
# 208      F   43.0  Central   60.0   Others   Science     65.00  Comm&Mgmt
# 214      M   62.0  Central   58.0   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
#to store the data of placed students
df_placed=dataset[dataset['status']=='Placed']
df_placed
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# 7        M  82.00  Central  64.00  Central   Science     66.00   Sci&Tech
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 209      M  62.00  Central  72.00  Central  Commerce     65.00  Comm&Mgmt
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
df_placed.describe()
# Out:
#             ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  148.000000  148.000000  148.000000  148.000000  148.000000
# mean    71.721486   69.926554   68.740541   73.238041   62.579392
# std      8.715445    9.329268    6.518087   13.729333    5.884583
# min     49.000000   50.830000   56.000000   50.000000   52.380000
# 25%     65.000000   63.000000   65.000000   60.000000   57.772500
# 50%     72.500000   68.000000   68.000000   72.000000   62.245000
# 75%     78.125000   75.250000   72.422500   85.000000   66.760000
# max     89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
df_nonplaced.describe()
# Out:
#            ssc_p      hsc_p   degree_p    etest_p      mba_p  salary
# count  67.000000  67.000000  67.000000  67.000000  67.000000    67.0
# mean   57.544030  58.395522  61.134179  69.587910  61.612836     0.0
# std     8.394246   9.914090   6.365825  11.930687   5.705689     0.0
# min    40.890000  37.000000  50.000000  50.000000  51.210000     0.0
# 25%    52.000000  51.000000  57.000000  60.000000  58.480000     0.0
# 50%    56.280000  60.330000  61.000000  67.000000  60.690000     0.0
# 75%    63.000000  64.000000  65.000000  76.500000  65.405000     0.0
# max    77.800000  82.000000  79.000000  97.000000  75.710000     0.0

# %%
def quanQual(df_placed):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if(df_placed[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")

            quan.append(columnName)
    return quan,qual

# %%
quan,qual=quanQual(df_placed)

# %%
quan
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
#to compare the mean score for placed and nonplaced students
describe=pd.DataFrame(index=['Mean_placed','Mean_Notplaced'],columns=quan)
for columnname in quan:
    describe[columnname]['Mean_placed']=df_placed[columnname].mean()
    describe[columnname]['Mean_Notplaced']=df_nonplaced[columnname].mean()
describe
# Out:
# C:\Users\RRDIL\AppData\Local\Temp\ipykernel_12856\3365548533.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   describe[columnname]['Mean_placed']=df_placed[columnname].mean()
# ...

# %% [markdown]
# #Based on the comparison of average scores, can able to justify that above 60 % mark in all the class students got placed. Below 60% in any of the class students are not placed.

# %% [markdown]
# ### 4) What kind of relation between salary and mba_p

# %%
dataset.corr(numeric_only=True)
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
# The correlation between the mba_p and salary it is directly proportional only 13%.if mba_p
# mark get increased salary also get increased but the increments ratio is only 13%.

# %% [markdown]
# ###  5)Which specialization is getting minimum salary?

# %%
df_placed["salary"].min()
# Out:
# 200000.0

# %% [markdown]
#  marketing and finance getting minimum value of salary

# %% [markdown]
# ### 6) How many of them getting above 500000 salaries?

# %%
salaries_above_500000=dataset[dataset["salary"]>500000]
salaries_count=len(salaries_above_500000)

print("The number of students getting above 500000 salary is:",salaries_count)
# Out:
# The number of students getting above 500000 salary is: 3

# %% [markdown]
# ### 7) Test the Analysis of Variance between etest_p and mba_p at signifance level 5%. (Make decision using Hypothesis Testing)

# %%
import scipy.stats as stats
stats.f_oneway(dataset['etest_p'],dataset['mba_p'])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %% [markdown]
# p0.05% means reject null hypothesis accept alternate hypothesis
# here  we get probability value is 4.6% .  4.6%<0.05%
#  so that we accept null hypothesis.
#  H0-There is no significant difference b/w entrance test pass mark and mba pass mark
#  H1-There is significant difference b/w entrance test pass mark and mba pass mark
#  so that it is in H0

# %% [markdown]
# ### 8)Test the similarity between the degree_t (Sci&Tech) and specialisation (Mkt&HR) with respect to salary at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
#Independent sample -unpaired T Test

#same Group(salary) but different condition(degree_t(Sci&Tech),specialisation(Mkt&HR))


from scipy.stats import ttest_ind
dataset=dataset.dropna()
degree_t=dataset[dataset['degree_t']=='Sci&Tech']['salary']
specialisation=dataset[dataset['specialisation']=='Mkt&HR']['salary']
t_stat,p_value=ttest_ind(degree_t,specialisation)
print(f"T-statistic:{t_stat},P-value:{p_value}")
# Out:
# T-statistic:2.692041243555374,P-value:0.007897969943471179

# %% [markdown]
# H0-There is no similarity between the degree_t(Sci&Tech ) and specialization(Mkt&HR) with respect to salary
# H1-There is  similarity between the degree_t(Sci&Tech ) and specialization(Mkt&HR) with respect to salary
#
# here the p value is less than 0.05 so it will reject the null hypothesis and accept  the alternate  hypothesis
# H1 is accepted

# %% [markdown]
# ### 9)What is the probability Density Function of the salary range from 700000 to 900000

# %%
def get_pdf_probability(dataset,startrange,endrange):
        from matplotlib import pyplot
        from scipy.stats import norm
        import seaborn as sns
       
   
        ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
         #first create distplot and then give the dataset we have to create curve so kde(kernel density function) is True and 
         #we put the curve colour is blue and histogram colour is green.
        
        pyplot.axvline(startrange,color='Red')
        # py plot axis(ax) vertical line in start range ,the colour of the line is "Red"
      
        pyplot.axvline(endrange,color='Red')
        # py plot axis(ax) vertical line in end range ,the colour of the line is "Red"
       
        #generate a sample
        sample=dataset
       
        #calculate parameters
        sample_mean=sample.mean()
        sample_std=sample.std()
        print('Mean=%.3f,Standard Deviation=%.3f' % (sample_mean,sample_std))
       
        #define the distribution
        dist=norm(sample_mean,sample_std)
        #normal distribution have inbuild function we give sample_mean,sample_standard deviation so it create the distribution function
      
        #sample probabilities for a range of outcomes
        values=[value for value in range(startrange, endrange)]
        #single line for loop
        
        probabilities=[dist.pdf(value) for value in values]
        #dist.pdf pass the value  create the probability
        
        prob=sum(probabilities)
        #summation the probabilities
        
        print("The area between range({},{}:{}".format(startrange,endrange,sum(probabilities)))
        return prob

# %%
get_pdf_probability(dataset["salary"],700000,900000)
# Out:
# C:\Users\RRDIL\AppData\Local\Temp\ipykernel_12856\1476344966.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# Mean=198702.326,Standard Deviation=154780.927
# The area between range(700000,900000:0.0005973310593974868
# 0.0005973310593974868

# %% [markdown]
# #salary value is increase only in0.00059 from 700000 to 900000

# %% [markdown]
# ### 10) Convert the normal distribution to standard normal distribution for salary column

# %%
def stdNBgraph(dataset):
 #converted to standard normal distribution
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()

    values=[i for i in dataset]
     #we pass the input dataset and the converted as list .
   
    z_score=[((j-mean)/std) for j in values]
    #calculate the zscore value from inliner for loop .
    
    sns.displot(z_score,kde=True)
    #plot the standard normal distribution graph.
    
    sum(z_score)/len(z_score)
    #z_score.std()

# %%
stdNBgraph(dataset["salary"])

# %% [markdown]
#  ### 11)Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%.(Make decision using Hypothesis Testing)

# %%
#dependent sample -paired T Test

#same Group degree_t(Sci&Tech) but different condition(etest_p and mba_p)

from scipy.stats import ttest_rel
dataset=dataset.dropna()
etest_p=dataset[dataset['degree_t']=='Sci&Tech']['etest_p']
mba_p=dataset[dataset['degree_t']=='Sci&Tech']['mba_p']

ttest_rel(etest_p,mba_p)
# Out:
# TtestResult(statistic=5.0049844583693615, pvalue=5.517920600505392e-06, df=58)

# %% [markdown]
# H0 - There is no similarity between the degree_t(Sci&Tech) with respect to etest_p.
#
# H1 - There is similarity between the degree_t(Sci&Tech) with respect to mba_p.
#
# Here the p value is greater than 0.05 so it will reject the alternate hypothesis and accepts the hypothesis.
#
# The H0 is accepted.

# %% [markdown]
#  ### 12) Which parameter is highly correlated with salary?

# %%
dataset.corr(numeric_only=True)
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly
print(plotly.__version__)
# Out:
# 5.24.1

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns 
plt.figure(figsize=(10,7))
corr_mat =dataset.corr(numeric_only=True)
sns.heatmap(corr_mat, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# the correlation between salary and ssc_p is 0.54, which is a moderately strong positive correlation.

# %% [markdown]
# ### 14)Plot any useful graph and explain it

# %%
sns.pairplot(dataset)
